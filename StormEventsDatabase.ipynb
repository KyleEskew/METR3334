# %%
import numpy as np
import pandas as pd
import glob
import matplotlib.pyplot as plt

# %%
fname='/data/esplab/shared/classes/metr3334/class_data/stormevents/StormEvents_details-ftp_v1.0_d2019_c20230118.csv'

# %%
storm_df=pd.read_csv(fname)
storm_df
# Out:
#        BEGIN_YEARMONTH  BEGIN_DAY  BEGIN_TIME  END_YEARMONTH  END_DAY  \
# 0               201905          9        1554         201905        9
# 1               201908          1           0         201908        7
# 2               201902         19        2226         201902       19
# 3               201902         19        2255         201902       19
# 4               201901         29        1200         201901       29
# ...                ...        ...         ...            ...      ...
# 67854           201908         23        1809         201908       23
# 67855           201908         28        1700         201908       28
# 67856           201908         28        1745         201908       28
# 67857           201908         28        1830         201908       28
# 67858           201908         28        1639         201908       28
#
#        END_TIME  EPISODE_ID  EVENT_ID          STATE  STATE_FIPS  ...  \
# 0          1830      137295    824116          TEXAS          48  ...
# 1          1400      141502    849617   SOUTH DAKOTA          46  ...
# 2          2350      134941    808922       ARKANSAS           5  ...
# 3          2355      134941    808923       ARKANSAS           5  ...
# 4          1900      133946    801726  WEST VIRGINIA          54  ...
# ...         ...         ...       ...            ...         ...  ...
# 67854      1817      141859    851546        ARIZONA           4  ...
# 67855      1733      141860    851549        ARIZONA           4  ...
# 67856      1745      141860    851550        ARIZONA           4  ...
# 67857      1830      141860    851551        ARIZONA           4  ...
# 67858      1639      141860    851864        ARIZONA           4  ...
#
#        END_RANGE END_AZIMUTH          END_LOCATION BEGIN_LAT  BEGIN_LON  \
# 0            7.0         NNE          SAN GERONIMO   29.7898   -98.6406
# 1            3.0           W                 BRUCE   44.5400   -96.9600
# 2            NaN         NaN                   NaN       NaN        NaN
# 3            NaN         NaN                   NaN       NaN        NaN
# 4            NaN         NaN                   NaN       NaN        NaN
# ...          ...         ...                   ...       ...        ...
# 67854        6.0         WNW  (FHU)FT HUACHUCA AFB   31.5920  -110.3288
# 67855        2.0         WNW  (DMA)DAVIS MONTHAN A   32.2500  -110.8236
# 67856        1.0           W              VAIVO VO   32.7200  -111.9300
# 67857       13.0           N          COPPER CREEK   32.9400  -110.4900
# 67858        6.0         SSW              VAIL JCT   31.9500  -110.7700
#
#        END_LAT   END_LON                                  EPISODE_NARRATIVE  \
# 0      29.7158  -98.7744  Thunderstorms developed along a cold front as ...
# 1      44.4300  -96.9400  Minor flooding slowly dwindled during early Au...
# 2          NaN       NaN  Rain was heavy at times on the 19th, and there...
# 3          NaN       NaN  Rain was heavy at times on the 19th, and there...
# 4          NaN       NaN  A strong surface cold front crossed the region...
# ...        ...       ...                                                ...
# 67854  31.6055 -110.4456  Scattered thunderstorms formed over a large pa...
# 67855  32.1755 -110.9109  Widespread thunderstorms formed during the aft...
# 67856  32.7200 -111.9300  Widespread thunderstorms formed during the aft...
# 67857  32.9400 -110.4900  Widespread thunderstorms formed during the aft...
# 67858  31.9500 -110.7700  Widespread thunderstorms formed during the aft...
#
#                                          EVENT_NARRATIVE DATA_SOURCE
# 0      Thunderstorms produced heavy rain that led to ...         CSV
# 1      A continuation of flooding from July, the Big ...         CSV
# 2      One-quarter inch of freezing rain was measured...         CSV
# 3      One-quarter inch of freezing rain was measured...         CSV
# 4      Snowfall amounts of 1 to 2 inches were observe...         CSV
# ...                                                  ...         ...
# 67854  KFHU and KALK ASOS weather stations measured t...         CSV
# 67855  Trees were downed and uprooted at Ajo and Alve...         CSV
# 67856  Five power poles were downed north of Via Vo F...         CSV
# 67857      Horse Camp RAWS recorded wind gust of 61 mph.         CSV
# 67858       Penny sized hail was reported south of Vail.         CSV
#
# [67859 rows x 51 columns]

# %%
storms_ok=storm_df.loc[storm_df['STATE'] == 'OKLAHOMA']

# %%
tordeath_ok=storms_ok.loc[(storms_ok['EVENT_TYPE'] == 'Tornado') & (storms_ok['DEATHS_DIRECT'] >0)]

# %%
files=glob.glob('/data/esplab/shared/classes/metr3334/class_data/stormevents/StormEvents_details-ftp_v1.0_d*_c*.csv')

# %%
storm_list=[]
for lcv in files:
    df=pd.read_csv(lcv, low_memory=False, encoding_errors='ignore')
    storm_list.append(df)
storms_all=pd.concat(storm_list)

# %%
sgp_tor=storms_all.loc[(storms_all['EVENT_TYPE'] == 'Tornado') & (storms_all['BEGIN_LAT'] >29) & (storms_all['BEGIN_LAT'] <40) & (storms_all['BEGIN_LON'] <-95) & (storms_all['BEGIN_LON'] >-105)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 sgp_tor=storms_all.loc[(storms_all['EVENT_TYPE'] == 'Tornado') & (storms_all['BEGIN_LAT'] >29) & (storms_all['BEGIN_LAT'] <40) & (storms_all['BEGIN_LON'] <-95) & (storms_all['BEGIN_LON'] >-105)]
#
# NameError: name 'storms_all' is not defined
